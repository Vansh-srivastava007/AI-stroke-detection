# %% [markdown]
# <a href="https://colab.research.google.com/github/Vansh-srivastava007/AI-stroke-detection/blob/main/strokesss.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as p
import matplotlib.pyplot as plt
import seaborn as s
import numpy as n
import warnings
warnings.filterwarnings('ignore')
data=p.read_csv('stroke.csv')
data
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# ...

# %%
data.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
data.shape
# Out:
# (5110, 12)

# %%
data.isnull()
# Out:
#          id  gender    age  hypertension  heart_disease  ever_married  \
# 0     False   False  False         False          False         False
# 1     False   False  False         False          False         False
# 2     False   False  False         False          False         False
# 3     False   False  False         False          False         False
# 4     False   False  False         False          False         False
# ...     ...     ...    ...           ...            ...           ...
# 5105  False   False  False         False          False         False
# 5106  False   False  False         False          False         False
# 5107  False   False  False         False          False         False
# 5108  False   False  False         False          False         False
# 5109  False   False  False         False          False         False
#
#       work_type  Residence_type  avg_glucose_level    bmi  smoking_status  \
# ...

# %%
data.isnull().sum()
# Out:
# id                     0
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# ever_married           0
# work_type              0
# Residence_type         0
# avg_glucose_level      0
# bmi                  201
# smoking_status         0
# stroke                 0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
df=data.dropna()

# %%
df.shape
# Out:
# (4909, 12)

# %%
df.isnull().sum()
# Out:
# id                   0
# gender               0
# age                  0
# hypertension         0
# heart_disease        0
# ever_married         0
# work_type            0
# Residence_type       0
# avg_glucose_level    0
# bmi                  0
# smoking_status       0
# stroke               0
# dtype: int64

# %%
df.columns
# Out:
# Index(['id', 'gender', 'age', 'hypertension', 'heart_disease', 'ever_married',
#        'work_type', 'Residence_type', 'avg_glucose_level', 'bmi',
#        'smoking_status', 'stroke'],
#       dtype='object')

# %%
df.describe()
# Out:
#                  id          age  hypertension  heart_disease  \
# count   4909.000000  4909.000000   4909.000000    4909.000000
# mean   37064.313506    42.865374      0.091872       0.049501
# std    20995.098457    22.555115      0.288875       0.216934
# min       77.000000     0.080000      0.000000       0.000000
# 25%    18605.000000    25.000000      0.000000       0.000000
# 50%    37608.000000    44.000000      0.000000       0.000000
# 75%    55220.000000    60.000000      0.000000       0.000000
# max    72940.000000    82.000000      1.000000       1.000000
#
#        avg_glucose_level          bmi       stroke
# count        4909.000000  4909.000000  4909.000000
# mean          105.305150    28.893237     0.042575
# std            44.424341     7.854067     0.201917
# min            55.120000    10.300000     0.000000
# 25%            77.070000    23.500000     0.000000
# 50%            91.680000    28.100000     0.000000
# ...

# %%
del df['id']
del df['age']

# %%
df.columns
# Out:
# Index(['gender', 'hypertension', 'heart_disease', 'ever_married', 'work_type',
#        'Residence_type', 'avg_glucose_level', 'bmi', 'smoking_status',
#        'stroke'],
#       dtype='object')

# %%
df.gender.unique()
# Out:
# array(['Male', 'Female', 'Other'], dtype=object)

# %%
df.hypertension.unique
# Out:
# <bound method Series.unique of 0       0
# 2       0
# 3       0
# 4       1
# 5       0
#        ..
# 5104    0
# 5106    0
# 5107    0
# 5108    0
# 5109    0
# Name: hypertension, Length: 4909, dtype: int64>

# %%
df.heart_disease.unique()
# Out:
# array([1, 0])

# %%
df.ever_married.unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df.work_type.unique()
# Out:
# array(['Private', 'Self-employed', 'Govt_job', 'children', 'Never_worked'],
#       dtype=object)

# %%
df.Residence_type.unique()
# Out:
# array(['Urban', 'Rural'], dtype=object)

# %%
df.avg_glucose_level.unique()
# Out:
# array([228.69, 105.92, 171.23, ...,  82.99, 166.29,  85.28])

# %%
df.bmi.unique()
# Out:
# array([36.6, 32.5, 34.4, 24. , 29. , 27.4, 22.8, 24.2, 29.7, 36.8, 27.3,
#        28.2, 30.9, 37.5, 25.8, 37.8, 22.4, 48.9, 26.6, 27.2, 23.5, 28.3,
#        44.2, 25.4, 22.2, 30.5, 26.5, 33.7, 23.1, 32. , 29.9, 23.9, 28.5,
#        26.4, 20.2, 33.6, 38.6, 39.2, 27.7, 31.4, 36.5, 33.2, 32.8, 40.4,
#        25.3, 30.2, 47.5, 20.3, 30. , 28.9, 28.1, 31.1, 21.7, 27. , 24.1,
#        45.9, 44.1, 22.9, 29.1, 32.3, 41.1, 25.6, 29.8, 26.3, 26.2, 29.4,
#        24.4, 28. , 28.8, 34.6, 19.4, 30.3, 41.5, 22.6, 56.6, 27.1, 31.3,
#        31. , 31.7, 35.8, 28.4, 20.1, 26.7, 38.7, 34.9, 25. , 23.8, 21.8,
#        27.5, 24.6, 32.9, 26.1, 31.9, 34.1, 36.9, 37.3, 45.7, 34.2, 23.6,
#        22.3, 37.1, 45. , 25.5, 30.8, 37.4, 34.5, 27.9, 29.5, 46. , 42.5,
#        35.5, 26.9, 45.5, 31.5, 33. , 23.4, 30.7, 20.5, 21.5, 40. , 28.6,
#        42.2, 29.6, 35.4, 16.9, 26.8, 39.3, 32.6, 35.9, 21.2, 42.4, 40.5,
#        36.7, 29.3, 19.6, 18. , 17.6, 19.1, 50.1, 17.7, 54.6, 35. , 22. ,
# ...

# %%
df.smoking_status.unique()
# Out:
# array(['formerly smoked', 'never smoked', 'smokes', 'Unknown'],
#       dtype=object)

# %%
df.stroke.unique()
# Out:
# array([1, 0])

# %%
df.columns
# Out:
# Index(['gender', 'hypertension', 'heart_disease', 'ever_married', 'work_type',
#        'Residence_type', 'avg_glucose_level', 'bmi', 'smoking_status',
#        'stroke'],
#       dtype='object')

# %%
p.crosstab(df.avg_glucose_level,df.smoking_status)
# Out:
# smoking_status     Unknown  formerly smoked  never smoked  smokes
# avg_glucose_level
# 55.12                    0                0             1       0
# 55.22                    0                0             1       0
# 55.23                    1                0             0       0
# 55.25                    0                0             1       0
# 55.26                    1                0             0       0
# ...                    ...              ...           ...     ...
# 266.59                   0                0             1       0
# 267.60                   0                0             1       0
# 267.61                   0                0             0       1
# 267.76                   0                1             0       0
# 271.74                   0                0             0       1
#
# [3852 rows x 4 columns]

# %%
p.Categorical(df['gender']).describe()
# Out:
#             counts     freqs
# categories
# Female        2897  0.590141
# Male          2011  0.409656
# Other            1  0.000204

# %%
p.Categorical(df['hypertension']).describe()
# Out:
#             counts     freqs
# categories
# 0             4458  0.908128
# 1              451  0.091872

# %%
p.Categorical(df['heart_disease']).describe()
# Out:
#             counts     freqs
# categories
# 0             4666  0.950499
# 1              243  0.049501

# %%
p.Categorical(df['work_type']).describe()
# Out:
#                counts     freqs
# categories
# Govt_job          630  0.128336
# Never_worked       22  0.004482
# Private          2811  0.572622
# Self-employed     775  0.157873
# children          671  0.136688

# %%
p.Categorical(df['Residence_type']).describe()
# Out:
#             counts     freqs
# categories
# Rural         2419  0.492768
# Urban         2490  0.507232

# %%
p.crosstab(df.hypertension,df.heart_disease)
# Out:
# heart_disease     0    1
# hypertension
# 0              4273  185
# 1               393   58

# %%
p.Categorical(df['smoking_status']).describe()
# Out:
#                  counts     freqs
# categories
# Unknown            1483  0.302098
# formerly smoked     837  0.170503
# never smoked       1852  0.377266
# smokes              737  0.150132

# %%
p.Categorical(df['avg_glucose_level']).describe()
# Out:
#             counts     freqs
# categories
# 55.12            1  0.000204
# 55.22            1  0.000204
# 55.23            1  0.000204
# 55.25            1  0.000204
# 55.26            1  0.000204
# ...            ...       ...
# 266.59           1  0.000204
# 267.60           1  0.000204
# 267.61           1  0.000204
# 267.76           1  0.000204
# 271.74           1  0.000204
#
# [3852 rows x 2 columns]

# %%
p.Categorical(df['bmi']).describe()
# Out:
#             counts     freqs
# categories
# 10.3             1  0.000204
# 11.3             1  0.000204
# 11.5             1  0.000204
# 12.0             1  0.000204
# 12.3             1  0.000204
# ...            ...       ...
# 66.8             1  0.000204
# 71.9             1  0.000204
# 78.0             1  0.000204
# 92.0             1  0.000204
# 97.6             1  0.000204
#
# [418 rows x 2 columns]

# %%
print("smoking_status:",sorted(df['smoking_status'].unique()))
# Out:
# smoking_status: ['Unknown', 'formerly smoked', 'never smoked', 'smokes']

# %%
print("average glucose level:",sorted(df['avg_glucose_level'].unique()))
# Out:
# average glucose level: [np.float64(55.12), np.float64(55.22), np.float64(55.23), np.float64(55.25), np.float64(55.26), np.float64(55.27), np.float64(55.28), np.float64(55.32), np.float64(55.34), np.float64(55.35), np.float64(55.39), np.float64(55.41), np.float64(55.42), np.float64(55.46), np.float64(55.47), np.float64(55.51), np.float64(55.57), np.float64(55.58), np.float64(55.59), np.float64(55.61), np.float64(55.62), np.float64(55.64), np.float64(55.67), np.float64(55.72), np.float64(55.78), np.float64(55.79), np.float64(55.83), np.float64(55.84), np.float64(55.86), np.float64(55.93), np.float64(55.96), np.float64(56.07), np.float64(56.08), np.float64(56.11), np.float64(56.12), np.float64(56.13), np.float64(56.18), np.float64(56.21), np.float64(56.23), np.float64(56.3), np.float64(56.31), np.float64(56.32), np.float64(56.33), np.float64(56.34), np.float64(56.37), np.float64(56.42), np.float64(56.43), np.float64(56.47), np.float64(56.48), np.float64(56.51), np.float64(56.63), np.flo
# ...

# %%
print("BMI:",sorted(df["bmi"].unique()))
# Out:
# BMI: [np.float64(10.3), np.float64(11.3), np.float64(11.5), np.float64(12.0), np.float64(12.3), np.float64(12.8), np.float64(13.0), np.float64(13.2), np.float64(13.3), np.float64(13.4), np.float64(13.5), np.float64(13.7), np.float64(13.8), np.float64(13.9), np.float64(14.0), np.float64(14.1), np.float64(14.2), np.float64(14.3), np.float64(14.4), np.float64(14.5), np.float64(14.6), np.float64(14.8), np.float64(14.9), np.float64(15.0), np.float64(15.1), np.float64(15.2), np.float64(15.3), np.float64(15.4), np.float64(15.5), np.float64(15.6), np.float64(15.7), np.float64(15.8), np.float64(15.9), np.float64(16.0), np.float64(16.1), np.float64(16.2), np.float64(16.3), np.float64(16.4), np.float64(16.5), np.float64(16.6), np.float64(16.7), np.float64(16.8), np.float64(16.9), np.float64(17.0), np.float64(17.1), np.float64(17.2), np.float64(17.3), np.float64(17.4), np.float64(17.5), np.float64(17.6), np.float64(17.7), np.float64(17.8), np.float64(17.9), np.float64(18.0), np.float64(18.1), np
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4909 entries, 0 to 5109
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   gender             4909 non-null   object
#  1   hypertension       4909 non-null   int64
#  2   heart_disease      4909 non-null   int64
#  3   ever_married       4909 non-null   object
#  4   work_type          4909 non-null   object
#  5   Residence_type     4909 non-null   object
#  6   avg_glucose_level  4909 non-null   float64
#  7   bmi                4909 non-null   float64
#  8   smoking_status     4909 non-null   object
#  9   stroke             4909 non-null   int64
# dtypes: float64(2), int64(3), object(5)
# memory usage: 421.9+ KB

# %%
df.duplicated()
# Out:
# 0       False
# 2       False
# 3       False
# 4       False
# 5       False
#         ...
# 5104    False
# 5106    False
# 5107    False
# 5108    False
# 5109    False
# Length: 4909, dtype: bool

# %%
df.columns
# Out:
# Index(['gender', 'hypertension', 'heart_disease', 'ever_married', 'work_type',
#        'Residence_type', 'avg_glucose_level', 'bmi', 'smoking_status',
#        'stroke'],
#       dtype='object')

# %%
print("Minimum value of glucose level is:",df.avg_glucose_level.min())
# Out:
# Minimum value of glucose level is: 55.12

# %%
print("Maximum glucose level is:",df.avg_glucose_level.max())
# Out:
# Maximum glucose level is: 271.74

# %%
print("Minimum value of BMI level is :",df.bmi.min())
# Out:
# Minimum value of BMI level is : 10.3

# %%
print("Maximum value of BMI level is :",df.bmi.max())
# Out:
# Maximum value of BMI level is : 97.6

# %%
from sklearn.preprocessing import LabelEncoder
var_mod=['gender','ever_married','work_type','Residence_type','smoking_status']
le=LabelEncoder()
for i in var_mod:
    df[i]=le.fit_transform(df[i]).astype(int)

# %%
df.head
# Out:
# <bound method NDFrame.head of       gender  hypertension  heart_disease  ever_married  work_type  \
# 0          1             0              1             1          2
# 2          1             0              1             1          2
# 3          0             0              0             1          2
# 4          0             1              0             1          3
# 5          1             0              0             1          2
# ...      ...           ...            ...           ...        ...
# 5104       0             0              0             0          4
# 5106       0             0              0             1          3
# 5107       0             0              0             1          3
# 5108       1             0              0             1          2
# 5109       0             0              0             1          0
#
#       Residence_type  avg_glucose_level   bmi  smoking_status  stroke
# ...

# %%
df['avg_glucose_level'].hist(figsize=(5,5),color='brown',alpha=1)
plt.xlabel('avg_glucose_level & bmi')
plt.ylabel('bmi')
plt.title('avg_glucose_level & bmi')
# Out:
# Text(0.5, 1.0, 'avg_glucose_level & bmi')

# %%
plt.boxplot(df['smoking_status'])
plt.show()

# %%
import seaborn as s
s.boxplot(df['work_type'],color='m')
# Out:
# <Axes: ylabel='work_type'>

# %%
fig,ax=plt.subplots(figsize=(16,8))
ax.scatter(df['avg_glucose_level'],df['bmi'])
ax.set_xlabel('avg_glucose_level')
ax.set_ylabel('bmi')
plt.show()

# %%
#prpogation by variable
def propbyvar(df,variable):
    dataframe_pie=df[variable].value_counts()
    ax=dataframe_pie.plot.pie(figsize=(8,8),autopct='%1.2f%%',fontsze=12)
    ax.set_title(variable+'\n',fontsize=15)
    return n.round(dataframe_pie/df.shape[0]*100,2)
    propbyvar(df,'work_type')

# %%
#heatmap plot
fig,ax=plt.subplots(figsize=(10,7))
s.heatmap(df.corr(),ax=ax,annot=True)
# Out:
# <Axes: >

# %%
plt.plot(df["hypertension"],df["bmi"],color='g')

# %%
plt.xlabel('hypertension')
plt.ylabel('bmi')
plt.title('stroke')
plt.show()

# %%
df.head()
# Out:
#    gender  hypertension  heart_disease  ever_married  work_type  \
# 0       1             0              1             1          2
# 2       1             0              1             1          2
# 3       0             0              0             1          2
# 4       0             1              0             1          3
# 5       1             0              0             1          2
#
#    Residence_type  avg_glucose_level   bmi  smoking_status  stroke
# 0               1             228.69  36.6               1       1
# 2               0             105.92  32.5               2       1
# 3               1             171.23  34.4               3       1
# 4               0             174.12  24.0               2       1
# 5               1             186.21  29.0               1       1

# %%
#splitting train test
X=df.drop(labels='stroke',axis=1)
Y=df.loc[:,'stroke']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.20,random_state=1,stratify=Y)
print("Number of training dataset :",len(X_train))
print("number of test dataset :",len(X_test))
print("Total number of dataset :",len(X_train)+len(X_test))
# Out:
# Number of training dataset : 3927
# number of test dataset : 982
# Total number of dataset : 4909

# %%
from sklearn.metrics import confusion_matrix,classification_report,matthews_corrcoef,cohen_kappa_score,accuracy_score,average_precision_score,roc_auc_score
from sklearn.metrics import accuracy_score,confusion_matrix
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score

# %%
 logR=LogisticRegression()

# %%
logR.fit(X_train,Y_train)
predictLR=logR.predict(X_test)

# %%
print("")
print('Classification report of Logistic Regression Result:')
print("")
print(classification_report(Y_test,predictLR))
# Out:
# Classification report of Logistic Regression Result:
#
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98       940
#            1       1.00      0.02      0.05        42
#
#     accuracy                           0.96       982
#    macro avg       0.98      0.51      0.51       982
# weighted avg       0.96      0.96      0.94       982

# %%
print("")
cm1=confusion_matrix(Y_test,predictLR)
print('confusion Matrix result of Logistic Regression is :\n',cm1)
print("")
sensitivity1=cm1[0,0]/(cm1[0,0]+cm1[0,1])
print('sensitivity:', sensitivity1)
print("")
specificity1=cm1[1,1]/(cm1[1,0]+cm1[0,1])
print('specificity:',specificity1)
print("")
# Out:
# confusion Matrix result of Logistic Regression is :
#  [[940   0]
#  [ 41   1]]
#
# sensitivity: 1.0
#
# specificity: 0.024390243902439025

# %%
accuracy=cross_val_score(logR,X,Y,scoring='accuracy')
print('cross validation test result of accuracy:')
print(accuracy)
print("")
print("accuracy result of logistic Regression is :",accuracy.mean()*100)
LR=accuracy.mean()*100
# Out:
# cross validation test result of accuracy:
# [0.95723014 0.95723014 0.95723014 0.9592668  0.95922528]
#
# accuracy result of logistic Regression is : 95.80365020937528
